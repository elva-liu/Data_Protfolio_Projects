# %%
# Neural Network
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanAbsoluteError, MeanSquaredError
import statsmodels.api as sm
import tensorflow as tf
import matplotlib.pyplot as plt
#from silence_tensorflow import silence_tensorflow
#silence_tensorflow()

# %%
# Check GPU Usage
print(tf.config.list_physical_devices('GPU'))
print(tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2.10.1

# %% [markdown]
# The Data has 198,744 timesteps (Months):
# - Training: 70% (139,121 hours, ~5,797 days, May 2002–Feb 2018)
# - Validation: 15% (2,9812, ~1,242 days, Mar 2018–Jul 2021)
# - Test: 15% (2,9812, ~1,242 days, Aug 2021–Dec 2024)
#
# Approximatelly 16 years of training data (capturing multiple seasonal cycles) while leaving enough for validation and testing.

# %%
# Load the Data
data = pd.read_csv('C:\\Users\\cb7en\\OneDrive\\Documentos\\Stats Master - Wei\\Energy Data\\Ontario Hourly Consumption\\merged_Demand.csv', index_col='Date', parse_dates=True)

# check end of the data
data.sort_index(inplace=True)

data.index = pd.to_datetime(data.index)

monthly_tot = data['Ontario Demand'].resample('M').sum()
monthly_tot.tail(10)
# Out:
# Date
# 2024-03-31    11484309
# 2024-04-30    10429148
# 2024-05-31    10683881
# 2024-06-30    11543786
# 2024-07-31    13026541
# 2024-08-31    12611122
# 2024-09-30    11264302
# 2024-10-31    10949216
# 2024-11-30    11248652
# 2024-12-31    12806403
# Freq: ME, Name: Ontario Demand, dtype: int64

# %%
# Lookback Window: 12 months (1 year) to capture seasonality, predicting the 13th month. With 272 months, this gives 259 sequences (272 - 12).
data = pd.Series(monthly_tot,
                 index=pd.date_range(start='2002-05-31', periods=272, freq='M'))

# Split data chronologically
train_size = 190
val_size = 41
test_size = 41

train_data = data[:train_size].values.reshape(-1, 1) # first 190 months
val_data = data[train_size:train_size + val_size].values.reshape(-1, 1) # after 190, next 41 months
test_data = data[train_size + val_size:].values.reshape(-1, 1) # after (190+41) the next following 41 months

# Robust scaling
scaler = RobustScaler()
train_scaled = scaler.fit_transform(train_data) # only the training data
val_scaled = scaler.transform(val_data)
test_scaled = scaler.transform(test_data)

# Create sequences
def create_sequences(data, lookback):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:i + lookback])
        y.append(data[i + lookback])
    return np.array(X), np.array(y)

lookback = 12  # 1 year of past data (first with 12 and then later with 24)
X_train, y_train = create_sequences(train_scaled, lookback)
X_val, y_val = create_sequences(val_scaled, lookback)
X_test, y_test = create_sequences(test_scaled, lookback)

print(X_train.shape)  # Should be (178, 12, 1): 190 - 12 = 178 sequences
print(X_val.shape)   # Should be (29, 12, 1): 41 - 12 = 29 sequences
print(X_test.shape) # Should be (29, 12, 1): 41 - 12 = 29 sequences
# Out:
# (178, 12, 1)
# (29, 12, 1)
# (29, 12, 1)

# %%
# Simple GRU
model = Sequential()
model.add(GRU(units=32, input_shape=(lookback, 1), return_sequences=False))
model.add(Dense(units=1))  # Predict next month's demand

model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 32)                3360
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 3,393
# Trainable params: 3,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=50, batch_size=16,
                    validation_data=(X_val, y_val), callbacks=[early_stopping])

# Predict and inverse transform
y_pred_scaled = model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred_scaled)
y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))

mae = mean_absolute_error(y_test_orig, y_pred)
print(f'Test MAE: {mae:,.2f}')

# Plot results
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 12/12 [==============================] - 5s 41ms/step - loss: 0.3619 - val_loss: 0.5410
# Epoch 2/50
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3465 - val_loss: 0.5141
# Epoch 3/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3390 - val_loss: 0.4953
# Epoch 4/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3312 - val_loss: 0.4799
# Epoch 5/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3170 - val_loss: 0.4489
# Epoch 6/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3021 - val_loss: 0.4290
# Epoch 7/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2852 - val_loss: 0.3881
# Epoch 8/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2698 - val_loss: 0.3510
# Epoch 9/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2583 - val_loss: 0.3179
# Epoch 10/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2440 - val_loss: 0.3072
# Epoch 11/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2413 - val_loss: 0.2793
# Epoch 12/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2266 - val_loss: 0.2768
# Epoch 13/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2191 - val_loss: 0.2356
# Epoch 14/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2182 - val_loss: 0.2256
# Epoch 15/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2075 - val_loss: 0.2193
# Epoch 16/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2086 - val_loss: 0.2866
# Epoch 17/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2088 - val_loss: 0.2366
# Epoch 18/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2045 - val_loss: 0.2030
# Epoch 19/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1980 - val_loss: 0.2086
# Epoch 20/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1924 - val_loss: 0.2171
# Epoch 21/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1915 - val_loss: 0.2204
# Epoch 22/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1935 - val_loss: 0.1988
# Epoch 23/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1843 - val_loss: 0.2130
# Epoch 24/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1856 - val_loss: 0.2223
# Epoch 25/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1921 - val_loss: 0.1858
# Epoch 26/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1841 - val_loss: 0.2401
# Epoch 27/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1791 - val_loss: 0.1991
# Epoch 28/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1791 - val_loss: 0.2122
# Epoch 29/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1748 - val_loss: 0.1971
# Epoch 30/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1730 - val_loss: 0.1880
# Epoch 31/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1778 - val_loss: 0.1926
# Epoch 32/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1764 - val_loss: 0.1967
# Epoch 33/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1665 - val_loss: 0.1669
# Epoch 34/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1674 - val_loss: 0.1774
# Epoch 35/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1626 - val_loss: 0.1917
# Epoch 36/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1636 - val_loss: 0.1769
# Epoch 37/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1579 - val_loss: 0.1893
# Epoch 38/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1578 - val_loss: 0.1679
# Epoch 39/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1558 - val_loss: 0.1647
# Epoch 40/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1544 - val_loss: 0.1778
# Epoch 41/50
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1477 - val_loss: 0.1888
# Epoch 42/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1530 - val_loss: 0.1784
# Epoch 43/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1567 - val_loss: 0.1628
# Epoch 44/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1489 - val_loss: 0.1826
# Epoch 45/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1469 - val_loss: 0.1741
# Epoch 46/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1427 - val_loss: 0.1755
# Epoch 47/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1404 - val_loss: 0.1613
# Epoch 48/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1514 - val_loss: 0.2127
# Epoch 49/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1395 - val_loss: 0.1563
# Epoch 50/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1372 - val_loss: 0.1633
# 1/1 [==============================] - 0s 286ms/step
# Test MAE: 383,304.55

# %%
# Simple LSTM
model_lstm = Sequential()
model_lstm.add(LSTM(units=32, input_shape=(lookback, 1), return_sequences=False))
model_lstm.add(Dense(units=1))
model_lstm.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

history_lstm = model_lstm.fit(X_train, y_train, epochs=50, batch_size=16,
                              validation_data=(X_val, y_val), callbacks=[early_stopping])

y_pred_lstm_scaled = model_lstm.predict(X_test)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm_scaled)
mae_lstm = mean_absolute_error(y_test_orig, y_pred_lstm)
print(f"LSTM Test MAE: {mae_lstm:,.2f}")

# Plot results
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred_lstm, label='Predicted')
plt.title('LSTM vs Original')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 12/12 [==============================] - 2s 46ms/step - loss: 0.3998 - val_loss: 0.6110
# Epoch 2/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.3566 - val_loss: 0.5269
# Epoch 3/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3332 - val_loss: 0.4685
# Epoch 4/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3248 - val_loss: 0.4291
# Epoch 5/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3194 - val_loss: 0.4185
# Epoch 6/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3099 - val_loss: 0.4266
# Epoch 7/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3083 - val_loss: 0.4147
# Epoch 8/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2968 - val_loss: 0.3951
# Epoch 9/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2919 - val_loss: 0.3877
# Epoch 10/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2847 - val_loss: 0.3879
# Epoch 11/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2782 - val_loss: 0.3866
# Epoch 12/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2704 - val_loss: 0.3602
# Epoch 13/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2611 - val_loss: 0.4074
# Epoch 14/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2595 - val_loss: 0.3615
# Epoch 15/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2568 - val_loss: 0.3282
# Epoch 16/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2465 - val_loss: 0.3495
# Epoch 17/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2390 - val_loss: 0.3406
# Epoch 18/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2418 - val_loss: 0.3463
# Epoch 19/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2285 - val_loss: 0.3277
# Epoch 20/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2288 - val_loss: 0.3232
# Epoch 21/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2261 - val_loss: 0.3407
# Epoch 22/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2215 - val_loss: 0.3061
# Epoch 23/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2130 - val_loss: 0.3354
# Epoch 24/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2181 - val_loss: 0.3009
# Epoch 25/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2225 - val_loss: 0.3051
# Epoch 26/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2185 - val_loss: 0.3201
# Epoch 27/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2195 - val_loss: 0.2788
# Epoch 28/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2006 - val_loss: 0.3133
# Epoch 29/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2068 - val_loss: 0.3121
# Epoch 30/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1993 - val_loss: 0.3087
# Epoch 31/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1959 - val_loss: 0.3744
# Epoch 32/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1861 - val_loss: 0.2860
# Epoch 33/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1822 - val_loss: 0.3180
# Epoch 34/50
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1811 - val_loss: 0.3123
# Epoch 35/50
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1812 - val_loss: 0.2893
# Epoch 36/50
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1940 - val_loss: 0.3480
# Epoch 37/50
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1802 - val_loss: 0.2808
# 1/1 [==============================] - 0s 295ms/step
# LSTM Test MAE: 477,379.28

# %%
# Comparison
print(f'GRU Test MAE: {mae:,.2f}')
print(f"LSTM Test MAE: {mae_lstm:,.2f}")


def min_test(GRU_x,LSTM_x):
    if GRU_x < LSTM_x:
        print("GRU performed better results")
        print(f'GRU is {((LSTM_x-GRU_x)/LSTM_x):.2%} better than LSTM')
    else:
        print("LSTM performed better results")
        print(f'LSTM is {((GRU_x-LSTM_x)/LSTM_x):.2%} better than GRU')

min_test(mae,mae_lstm)
# Out:
# GRU Test MAE: 383,304.55
# LSTM Test MAE: 477,379.28
# GRU performed better results
# GRU is 19.71% better than LSTM

# %% [markdown]
# Increase the complexity of the Neural Networks
#
# - add more layers and neurons
# - first use the 12 months and compare with previous 12 months

# %%
# adding complexity to the networks
# data preparation (scaler, create_sequences) is unchanged
lookback = 12  # Updated lookback

# Enhanced GRU Model
model_gru = Sequential()
model_gru.add(GRU(units=64, input_shape=(lookback, 1), return_sequences=True))  # First GRU layer
model_gru.add(Dropout(0.2))  # 20% dropout to reduce overfitting
model_gru.add(GRU(units=32, return_sequences=False))  # Second GRU layer
model_gru.add(Dropout(0.2)) # another Dropout (20%) to prevent overfitting.
model_gru.add(Dense(units=16, activation='relu'))  # Additional dense layer
model_gru.add(Dense(units=1))  # Output layer

model_gru.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
model_gru.summary()

# Training
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history_gru = model_gru.fit(X_train, y_train, epochs=100, batch_size=16,
                            validation_data=(X_val, y_val), callbacks=[early_stopping])

# Predict and evaluate
y_pred_gru_scaled = model_gru.predict(X_test)
y_pred_gru = scaler.inverse_transform(y_pred_gru_scaled)
mae_gru = mean_absolute_error(y_test_orig, y_pred_gru)
print(f"Enhanced GRU Test MAE: {mae_gru:,.2f}")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 12, 64)            12864
#
#  dropout (Dropout)           (None, 12, 64)            0
#
#  gru_2 (GRU)                 (None, 32)                9408
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 22,817
# Trainable params: 22,817
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 [==============================] - 3s 75ms/step - loss: 0.4260 - val_loss: 0.7468
# Epoch 2/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.3791 - val_loss: 0.6020
# Epoch 3/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3621 - val_loss: 0.4842
# Epoch 4/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3618 - val_loss: 0.4701
# Epoch 5/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.3415 - val_loss: 0.5293
# Epoch 6/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3413 - val_loss: 0.5072
# Epoch 7/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3372 - val_loss: 0.4705
# Epoch 8/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3243 - val_loss: 0.4354
# Epoch 9/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3239 - val_loss: 0.4181
# Epoch 10/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3363 - val_loss: 0.4304
# Epoch 11/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2909 - val_loss: 0.3789
# Epoch 12/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2832 - val_loss: 0.3662
# Epoch 13/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2849 - val_loss: 0.3745
# Epoch 14/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2704 - val_loss: 0.3640
# Epoch 15/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2692 - val_loss: 0.2901
# Epoch 16/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2686 - val_loss: 0.3973
# Epoch 17/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2455 - val_loss: 0.2984
# Epoch 18/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2535 - val_loss: 0.3249
# Epoch 19/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2360 - val_loss: 0.2518
# Epoch 20/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2405 - val_loss: 0.3125
# Epoch 21/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2215 - val_loss: 0.2204
# Epoch 22/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2215 - val_loss: 0.2442
# Epoch 23/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2315 - val_loss: 0.2677
# Epoch 24/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2322 - val_loss: 0.2257
# Epoch 25/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2098 - val_loss: 0.2755
# Epoch 26/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2366 - val_loss: 0.2393
# Epoch 27/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2141 - val_loss: 0.1948
# Epoch 28/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2072 - val_loss: 0.2179
# Epoch 29/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1832 - val_loss: 0.2031
# Epoch 30/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1903 - val_loss: 0.2007
# Epoch 31/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1823 - val_loss: 0.2044
# Epoch 32/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2029 - val_loss: 0.1922
# Epoch 33/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1769 - val_loss: 0.1948
# Epoch 34/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1769 - val_loss: 0.2190
# Epoch 35/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1936 - val_loss: 0.1902
# Epoch 36/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1922 - val_loss: 0.2936
# Epoch 37/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1838 - val_loss: 0.1820
# Epoch 38/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1682 - val_loss: 0.2141
# Epoch 39/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1615 - val_loss: 0.2592
# Epoch 40/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1617 - val_loss: 0.1892
# Epoch 41/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1468 - val_loss: 0.2167
# Epoch 42/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1569 - val_loss: 0.2089
# Epoch 43/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1410 - val_loss: 0.1694
# Epoch 44/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1361 - val_loss: 0.1766
# Epoch 45/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1457 - val_loss: 0.2122
# Epoch 46/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1391 - val_loss: 0.2147
# Epoch 47/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1426 - val_loss: 0.1705
# Epoch 48/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1376 - val_loss: 0.1996
# Epoch 49/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1232 - val_loss: 0.1837
# Epoch 50/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1403 - val_loss: 0.1923
# Epoch 51/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1351 - val_loss: 0.1869
# Epoch 52/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1351 - val_loss: 0.1797
# Epoch 53/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1339 - val_loss: 0.1681
# Epoch 54/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1378 - val_loss: 0.2148
# Epoch 55/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1426 - val_loss: 0.1704
# Epoch 56/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1345 - val_loss: 0.2053
# Epoch 57/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1320 - val_loss: 0.1898
# Epoch 58/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1455 - val_loss: 0.1883
# Epoch 59/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1291 - val_loss: 0.1797
# Epoch 60/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1197 - val_loss: 0.1820
# Epoch 61/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1410 - val_loss: 0.1811
# Epoch 62/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1212 - val_loss: 0.2457
# Epoch 63/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1258 - val_loss: 0.1771
# 1/1 [==============================] - 1s 504ms/step
# Enhanced GRU Test MAE: 388,447.72

# %%
# Enhanced LSTM Model
model_lstm = Sequential()
model_lstm.add(LSTM(units=64, input_shape=(lookback, 1), return_sequences=True))  # First LSTM layer
model_lstm.add(Dropout(0.2)) # Dropout (20%) to prevent overfitting
model_lstm.add(LSTM(units=32, return_sequences=False))  # Second LSTM layer
model_lstm.add(Dropout(0.2)) #$ another Dropout (20%) to prevent overfitting
model_lstm.add(Dense(units=16, activation='relu'))  # Additional dense layer
model_lstm.add(Dense(units=1))  # Output layer

model_lstm.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
model_lstm.summary()

# Training
history_lstm = model_lstm.fit(X_train, y_train, epochs=100, batch_size=16,
                              validation_data=(X_val, y_val), callbacks=[early_stopping])

# Predict and evaluate
y_pred_lstm_scaled = model_lstm.predict(X_test)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm_scaled)
mae_lstm = mean_absolute_error(y_test_orig, y_pred_lstm)
print(f"Enhanced LSTM Test MAE: {mae_lstm:,.2f}")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 12, 64)            16896
#
#  dropout_2 (Dropout)         (None, 12, 64)            0
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 29,857
# Trainable params: 29,857
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 [==============================] - 3s 97ms/step - loss: 0.4063 - val_loss: 0.5447
# Epoch 2/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3445 - val_loss: 0.4082
# Epoch 3/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3230 - val_loss: 0.3890
# Epoch 4/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3304 - val_loss: 0.4267
# Epoch 5/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3220 - val_loss: 0.3690
# Epoch 6/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.3160 - val_loss: 0.3908
# Epoch 7/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2944 - val_loss: 0.4238
# Epoch 8/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3020 - val_loss: 0.4688
# Epoch 9/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3054 - val_loss: 0.3845
# Epoch 10/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2959 - val_loss: 0.3497
# Epoch 11/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2860 - val_loss: 0.4843
# Epoch 12/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3040 - val_loss: 0.4063
# Epoch 13/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2820 - val_loss: 0.3612
# Epoch 14/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2817 - val_loss: 0.3656
# Epoch 15/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2710 - val_loss: 0.3687
# Epoch 16/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2570 - val_loss: 0.3497
# Epoch 17/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2646 - val_loss: 0.3324
# Epoch 18/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3231 - val_loss: 0.4754
# Epoch 19/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2756 - val_loss: 0.3113
# Epoch 20/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2774 - val_loss: 0.3827
# Epoch 21/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2648 - val_loss: 0.3707
# Epoch 22/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2592 - val_loss: 0.3673
# Epoch 23/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2552 - val_loss: 0.3584
# Epoch 24/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2430 - val_loss: 0.3485
# Epoch 25/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2445 - val_loss: 0.3182
# Epoch 26/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2481 - val_loss: 0.3203
# Epoch 27/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2468 - val_loss: 0.2863
# Epoch 28/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2379 - val_loss: 0.3372
# Epoch 29/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2465 - val_loss: 0.2734
# Epoch 30/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2929 - val_loss: 0.2712
# Epoch 31/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2517 - val_loss: 0.2499
# Epoch 32/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2477 - val_loss: 0.2955
# Epoch 33/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2254 - val_loss: 0.3381
# Epoch 34/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2313 - val_loss: 0.2583
# Epoch 35/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2303 - val_loss: 0.2506
# Epoch 36/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2622 - val_loss: 0.3021
# Epoch 37/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2543 - val_loss: 0.3244
# Epoch 38/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2228 - val_loss: 0.3574
# Epoch 39/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2142 - val_loss: 0.2515
# Epoch 40/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2288 - val_loss: 0.2792
# Epoch 41/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.2226 - val_loss: 0.2520
# 1/1 [==============================] - 1s 588ms/step
# Enhanced LSTM Test MAE: 489,990.41

# %%
min_test(mae_gru,mae_lstm)
# Out:
# GRU performed better results
# GRU is 20.72% better than LSTM

# %% [markdown]
# Adding Temperature Ontario
# - Temperature Data was retrieved from a combination of 2 Weather Stations Located in province of Ontario
# - Environment Canada website: https://climate.weather.gc.ca/historical_data/search_historic_data_e.html
# - Data is mostly in Temperature per hour
#
# TORONTO CITY
# - Station Name: (TORONTO CITY) TAO weather station (University of Toronto Atmospheric Observatory)
# - Location: McLennan Physical Laboratory, 60 St George St, Toronto, ON, CANADA
# - Coordinates: 43.66° North Latitude and 79.4° West Longitude
#
# Name: VINELAND STATION RCS.
# - Location: Vineland, ON.
# - Proximity: It is 18.54 km from St. Catharines/Niagara District A.
# - Coordinates: 43.1538888, -79.3922221999999

# %%
# Load Weather data
weather_data = pd.read_csv("C:\\Users\\cb7en\\OneDrive\\Documentos\\Stats Master - Wei\\Energy Data\\Weather\\Ontario_Temp.csv", index_col='Date/Time (LST)', parse_dates=True)

# check end of the data
weather_data.head(3)
# Out:
#                      Year  Month  Day Time (LST)  Temp (°C)
# Date/Time (LST)
# 2002-05-01 00:00:00  2002      5    1       0:00        5.8
# 2002-05-01 01:00:00  2002      5    1       1:00        5.2
# 2002-05-01 02:00:00  2002      5    1       2:00        3.9

# %%
# handling missing values
print("Missing Values: ", weather_data['Temp (°C)'].isna().sum())

# Apply Linear interpolation
weather_data['Temp (°C)'] = weather_data['Temp (°C)'].interpolate(methopd='linear')
print("Missing values after interpolation: ", weather_data['Temp (°C)'].isna().sum())
# Out:
# Missing Values:  2912
# Missing values after interpolation:  0

# %%
# saving clean data
weather_data.to_csv('cleaned_temperature_hourly.csv')

# %%
# Weather average monthly temperature
weather_monthly =  weather_data['Temp (°C)'].resample('M').mean()

# checking data alignment from monthly Energy Demand + temperature
print('Data length Energy (monthly): ',len(monthly_tot))
print('Data length Temperature (monthly): ',len(weather_monthly))
# Out:
# Data length Energy (monthly):  272
# Data length Temperature (monthly):  272

# %%
# quantiles
quantiles = weather_monthly.quantile([0.05, 0.25, 0.50, 0.75, 0.95])
#print("Quantiles:")
#print(quantiles)

# add color to quantiles to identiy each one
quantile_colors = {0.05: 'red', 0.25: 'orange', 0.50: 'green', 0.75: 'black', 0.95: 'purple'}

# Time Series Plot with Quantile Lines
plt.figure(figsize=(12, 6)) #,facecolor='lightpink')
plt.plot(weather_monthly.index, weather_monthly, label='Energy Demand', color='black', alpha=0.5) # color='blue'

# Loop to indentify quantiles and set lines through plot
for q, value in quantiles.items():
    plt.axhline(y=value, color=quantile_colors[q], linestyle='--', alpha=0.7, label=f'{int(q*100)}th Percentile ({value:.2f})')

plt.annotate(f'Temp Max \n {round(weather_monthly.max(),2)}°C',xy=(weather_monthly.idxmax(), weather_monthly.max()), xytext=(80, -10), textcoords="offset points",
           ha='center', arrowprops=dict(facecolor='black', shrink=0.05),horizontalalignment='right', verticalalignment='bottom',
           bbox=dict(boxstyle="round,pad=0.5", fc="green", alpha=0.3))
plt.annotate(f'Tem Min \n {round(weather_monthly.min(),2)}°C',xy=(weather_monthly.idxmin(), weather_monthly.min()), xytext=(-80, -10), textcoords="offset points",
           ha='center', arrowprops=dict(facecolor='black', shrink=0.05),horizontalalignment='right', verticalalignment='bottom',
           bbox=dict(boxstyle="round,pad=0.5", fc="red", alpha=0.3))
asx = plt.gca()
# asx.set_facecolor('lightblue')
plt.title('Ontario Monthly Average Temperature (2002 Jun -2024 Dec) with Quantile Lines')
plt.xlabel('Date / Years')
plt.ylabel('Temperature')
plt.legend()
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()

fig = plt.gcf()
fig.savefig("pics\\energy_2.png", dpi=300)
plt.show()

# %%
# Combine Energy + Temperature
combined_data = pd.DataFrame({
    'Energy': monthly_tot,
    'Temeprature': weather_monthly
})

combined_data.head(3)
# Out:
#               Energy  Temeprature
# 2002-05-31  11874901    11.082124
# 2002-06-30  12185238    18.454792
# 2002-07-31  14033343    24.051815

# %%
# Drop any NaN rows (if any) and adjust temperature decimal places
combined_data = combined_data.dropna()
combined_data['Temeprature'] = combined_data['Temeprature'].apply(lambda x: round(x,0))
combined_data.head(5)
# Out:
#               Energy  Temeprature
# 2002-05-31  11874901         11.0
# 2002-06-30  12185238         18.0
# 2002-07-31  14033343         24.0
# 2002-08-31  13748878         23.0
# 2002-09-30  12593138         20.0

# %%
import matplotlib.ticker as ticker
# Create the plot
fig, ax1 = plt.subplots(figsize=(16,7))

# Plot first dataset on primary y-axis (left)
ax1.plot(combined_data['Energy'], 'b-', label='Energy')
ax1.set_xlabel('Date / Time')
ax1.set_ylabel('Energy Megawatts', color='b')
ax1.tick_params(axis='y', labelcolor='b')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
# Create second y-axis sharing the same x-axis
ax2 = ax1.twinx()

# Plot second dataset on secondary y-axis (right)
ax2.plot(combined_data['Temeprature'], 'r-', label='Temperature')
ax2.set_ylabel('Temperature °C', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Add titles and adjust layout
plt.title("Energy Demand vs Temperature Ontario Monthly Energy Demand Aug 2003 - Dec 2024",fontsize=15, pad=15)
fig.tight_layout()

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Display the plot
plt.show()

# %%
import seaborn as sns
sns.clustermap(combined_data.corr('spearman'), annot=True, center=0, cmap='Blues')
cmap = sns.diverging_palette(10, 220, as_cmap=True)
sns.clustermap(combined_data.corr(), annot=True, cmap=cmap, center=0);

# %%
# Normalize the data for Energy and temperature be the same scale
scaler_combined = RobustScaler()
scaled_combine_data = scaler_combined.fit_transform(combined_data)

# Shape of Dat is 2 now, Create a sequence to lookback in the data (adapitable for 24 months)
lookback2 = 12
X, y = [], []
for i in range(lookback2, len(scaled_combine_data)):
    X.append(scaled_combine_data[i-lookback2:i])
    y.append(scaled_combine_data[i,0])
X, y = np.array(X), np.array(y)

# Split data into training, validation and testing sets (70-15-15)
training_set = int(len(X)*0.7)
valuation_set = int(len(X)*.15)
X_tr, X_v, X_te = X[:training_set],X[training_set:training_set+valuation_set], X[training_set+valuation_set:]
y_tr, y_v, y_te = y[:training_set],y[training_set:training_set+valuation_set], y[training_set+valuation_set:]

# %%
# Enhanced GRU model
model_gru_t = Sequential()
model_gru_t.add(GRU(units=64, input_shape=(lookback2, 2), return_sequences=True))
model_gru_t.add(Dropout(0.2))
model_gru_t.add(GRU(units=32, return_sequences=False))
model_gru_t.add(Dropout(0.2))
model_gru_t.add(Dense(units=16, activation='relu'))
model_gru_t.add(Dense(units=1)) # Final selection

model_gru_t.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
model_gru_t.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 12, 64)            13056
#
#  dropout_4 (Dropout)         (None, 12, 64)            0
#
#  gru_4 (GRU)                 (None, 32)                9408
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 23,009
# Trainable params: 23,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training GRU
early_stop_t = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
his_gru = model_gru_t.fit(X_tr, y_tr, epochs=100, batch_size=16, validation_data=(X_v, y_v), callbacks=[early_stop_t])

# Prediction and Evaluation
y_pred_gru_scaled_t = model_gru_t.predict(X_te)
y_pred_gru_scaled_t_full = np.zeros((len(y_pred_gru_scaled_t),2)) # reconstruct 2D Inverse scaling
y_pred_gru_scaled_t_full[:,0] = y_pred_gru_scaled_t[:,0]  # prediction Energy
y_pred_gru_ener = scaler.inverse_transform(y_pred_gru_scaled_t_full)[:,0] # get energy
y_test_orig_t = scaler.inverse_transform(np.column_stack((y_te,X_te[:,-1,1])))[:,0]
mae_gru_t = mean_absolute_error(y_test_orig_t,y_pred_gru_ener)
print(f"GRU with Temperature Test MAE: {mae_gru_t:,.2f}")
# Out:
# Epoch 1/100
# 12/12 [==============================] - 3s 66ms/step - loss: 0.3392 - val_loss: 0.4362
# Epoch 2/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.2736 - val_loss: 0.3966
# Epoch 3/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.2702 - val_loss: 0.3652
# Epoch 4/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.2528 - val_loss: 0.3300
# Epoch 5/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2270 - val_loss: 0.3032
# Epoch 6/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2189 - val_loss: 0.2740
# Epoch 7/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1899 - val_loss: 0.2389
# Epoch 8/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1852 - val_loss: 0.2289
# Epoch 9/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1795 - val_loss: 0.1952
# Epoch 10/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1504 - val_loss: 0.1845
# Epoch 11/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1507 - val_loss: 0.1660
# Epoch 12/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1608 - val_loss: 0.1612
# Epoch 13/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1423 - val_loss: 0.1489
# Epoch 14/100
# 12/12 [==============================] - 0s 18ms/step - loss: 0.1270 - val_loss: 0.1351
# Epoch 15/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1315 - val_loss: 0.1466
# Epoch 16/100
# 12/12 [==============================] - 0s 18ms/step - loss: 0.1330 - val_loss: 0.1437
# Epoch 17/100
# 12/12 [==============================] - 0s 21ms/step - loss: 0.1249 - val_loss: 0.1334
# Epoch 18/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.1236 - val_loss: 0.1459
# Epoch 19/100
# 12/12 [==============================] - 0s 18ms/step - loss: 0.1374 - val_loss: 0.1281
# Epoch 20/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.1185 - val_loss: 0.1178
# Epoch 21/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1192 - val_loss: 0.1200
# Epoch 22/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.1121 - val_loss: 0.1282
# Epoch 23/100
# 12/12 [==============================] - 0s 23ms/step - loss: 0.1077 - val_loss: 0.1088
# Epoch 24/100
# 12/12 [==============================] - 0s 19ms/step - loss: 0.1172 - val_loss: 0.1284
# Epoch 25/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1101 - val_loss: 0.1095
# Epoch 26/100
# 12/12 [==============================] - 0s 19ms/step - loss: 0.1192 - val_loss: 0.1057
# Epoch 27/100
# 12/12 [==============================] - 0s 24ms/step - loss: 0.1194 - val_loss: 0.1079
# Epoch 28/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.1194 - val_loss: 0.1134
# Epoch 29/100
# 12/12 [==============================] - 0s 17ms/step - loss: 0.1148 - val_loss: 0.1144
# Epoch 30/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1004 - val_loss: 0.1159
# Epoch 31/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1179 - val_loss: 0.1078
# Epoch 32/100
# 12/12 [==============================] - 0s 18ms/step - loss: 0.1157 - val_loss: 0.1194
# Epoch 33/100
# 12/12 [==============================] - 0s 19ms/step - loss: 0.1103 - val_loss: 0.1007
# Epoch 34/100
# 12/12 [==============================] - 0s 19ms/step - loss: 0.1053 - val_loss: 0.1092
# Epoch 35/100
# 12/12 [==============================] - 0s 20ms/step - loss: 0.1164 - val_loss: 0.1113
# Epoch 36/100
# 12/12 [==============================] - 0s 18ms/step - loss: 0.1174 - val_loss: 0.1077
# Epoch 37/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1232 - val_loss: 0.1104
# Epoch 38/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1022 - val_loss: 0.1080
# Epoch 39/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1073 - val_loss: 0.1132
# Epoch 40/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1025 - val_loss: 0.1269
# Epoch 41/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1112 - val_loss: 0.1145
# Epoch 42/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1150 - val_loss: 0.1166
# Epoch 43/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1144 - val_loss: 0.1011
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002589577B040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 5ms/step
# GRU with Temperature Test MAE: 277,898.99

# %%
# Enhanced LSTM Model
model_lstm_t = Sequential()
model_lstm_t.add(LSTM(units=64, input_shape=(lookback2, 2), return_sequences=True))
model_lstm_t.add(Dropout(0.2))
model_lstm_t.add(LSTM(units=32, return_sequences=False))
model_lstm_t.add(Dropout(0.2))
model_lstm_t.add(Dense(units=16, activation='relu'))
model_lstm_t.add(Dense(units=1))

model_lstm_t.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
model_lstm_t.summary()

# Training
his_lstm_t = model_lstm.fit(X_tr, y_tr, epochs=100, batch_size=16, validation_data=(X_v, y_v), callbacks=[early_stop_t])

# Predict and evaluate
y_pred_lstm_scaled_t = model_lstm_t.predict(X_te)
y_pred_lstm_scaled_t_full = np.zeros((len(y_pred_lstm_scaled_t), 2))
y_pred_lstm_scaled_t_full[:, 0] = y_pred_lstm_scaled_t[:, 0]
y_pred_lstm_t = scaler.inverse_transform(y_pred_lstm_scaled_t_full)[:, 0]
mae_lstm_t = mean_absolute_error(y_test_orig_t, y_pred_lstm_t)
print(f"LSTM with Temperature Test MAE: {mae_lstm_t:,.2f}")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 12, 64)            17152
#
#  dropout_6 (Dropout)         (None, 12, 64)            0
#
#  lstm_4 (LSTM)               (None, 32)                12416
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 16)                528
#
#  dense_9 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 30,113
# Trainable params: 30,113
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 12/12 [==============================] - 3s 86ms/step - loss: 0.3990 - val_loss: 0.4119
# Epoch 2/100
# 12/12 [==============================] - 0s 18ms/step - loss: 0.3072 - val_loss: 0.3808
# Epoch 3/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3214 - val_loss: 0.3842
# Epoch 4/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.2870 - val_loss: 0.3800
# Epoch 5/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2963 - val_loss: 0.3848
# Epoch 6/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2803 - val_loss: 0.3940
# Epoch 7/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.3135 - val_loss: 0.3769
# Epoch 8/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2832 - val_loss: 0.4179
# Epoch 9/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2581 - val_loss: 0.3926
# Epoch 10/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2516 - val_loss: 0.3785
# Epoch 11/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2364 - val_loss: 0.3785
# Epoch 12/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.3046 - val_loss: 0.3740
# Epoch 13/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2529 - val_loss: 0.3864
# Epoch 14/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2840 - val_loss: 0.3799
# Epoch 15/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2751 - val_loss: 0.3724
# Epoch 16/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2623 - val_loss: 0.3845
# Epoch 17/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2678 - val_loss: 0.3688
# Epoch 18/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2598 - val_loss: 0.3626
# Epoch 19/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.2442 - val_loss: 0.3568
# Epoch 20/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2349 - val_loss: 0.3610
# Epoch 21/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2327 - val_loss: 0.3618
# Epoch 22/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2423 - val_loss: 0.3619
# Epoch 23/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2362 - val_loss: 0.3663
# Epoch 24/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2267 - val_loss: 0.3529
# Epoch 25/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2245 - val_loss: 0.3329
# Epoch 26/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2216 - val_loss: 0.3306
# Epoch 27/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2177 - val_loss: 0.3354
# Epoch 28/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2375 - val_loss: 0.3392
# Epoch 29/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2282 - val_loss: 0.3338
# Epoch 30/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2260 - val_loss: 0.3279
# Epoch 31/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1956 - val_loss: 0.3071
# Epoch 32/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2517 - val_loss: 0.3240
# Epoch 33/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2118 - val_loss: 0.3323
# Epoch 34/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2158 - val_loss: 0.3220
# Epoch 35/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2612 - val_loss: 0.3133
# Epoch 36/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2175 - val_loss: 0.3123
# Epoch 37/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2110 - val_loss: 0.3133
# Epoch 38/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2151 - val_loss: 0.3141
# Epoch 39/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2048 - val_loss: 0.3033
# Epoch 40/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1938 - val_loss: 0.2955
# Epoch 41/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2110 - val_loss: 0.3507
# Epoch 42/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2321 - val_loss: 0.3036
# Epoch 43/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2090 - val_loss: 0.2920
# Epoch 44/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2195 - val_loss: 0.3086
# Epoch 45/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1882 - val_loss: 0.3351
# Epoch 46/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2369 - val_loss: 0.2983
# Epoch 47/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2002 - val_loss: 0.2968
# Epoch 48/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2092 - val_loss: 0.2950
# Epoch 49/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.2085 - val_loss: 0.3175
# Epoch 50/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1927 - val_loss: 0.2941
# Epoch 51/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1829 - val_loss: 0.2886
# Epoch 52/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1920 - val_loss: 0.3131
# Epoch 53/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1968 - val_loss: 0.2781
# Epoch 54/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1967 - val_loss: 0.3099
# Epoch 55/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1944 - val_loss: 0.2817
# Epoch 56/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1859 - val_loss: 0.2951
# Epoch 57/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1746 - val_loss: 0.2731
# Epoch 58/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1749 - val_loss: 0.2598
# Epoch 59/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1908 - val_loss: 0.2796
# Epoch 60/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1879 - val_loss: 0.2634
# Epoch 61/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1818 - val_loss: 0.2796
# Epoch 62/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1897 - val_loss: 0.2890
# Epoch 63/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1905 - val_loss: 0.2955
# Epoch 64/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1643 - val_loss: 0.2848
# Epoch 65/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.1765 - val_loss: 0.2787
# Epoch 66/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1842 - val_loss: 0.2763
# Epoch 67/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1559 - val_loss: 0.2772
# Epoch 68/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1644 - val_loss: 0.2694
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000258AEA96D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 5ms/step
# LSTM with Temperature Test MAE: 724,795.00

# %%
min_test(mae_gru_t,mae_lstm_t)
# Out:
# GRU performed better results
# GRU is 61.66% better than LSTM
